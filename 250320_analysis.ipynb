# %%
import os
from nd2reader import ND2Reader
import napari
import numpy as np
from cellpose import models
from skimage.measure import regionprops_table
from skimage.io import imsave
from skimage.segmentation import clear_border
from skimage.transform import resize
from skimage.morphology import remove_small_objects
import pandas as pd
from skimage.feature import blob_dog, blob_log
from utils import sharpest_frame_laplacian, mask_from_df
from scipy.spatial.distance import cdist

# %%
model = models.Cellpose(gpu=True, model_type='cyto2')

# define distances for the analysis of pairs
dist_list = [2,4,6]

# define sensitivity for the foci detection 
foci1_threshold = 0.01
foci2_threshold = 0.005

# define nulcei sizes
min_area = 2000
max_area = 20000
cell_diameter = 60

# %%
# pathway to the directory with the images
data_dir = r'I:\CBI\Kasia\data_analysis\2025_Fouquerel\data\53BP1 IF cenpB FISH -Lily'

# pahtway to a directory to store the results (doesn't have to exist)
masks_dir = r'I:\CBI\Kasia\data_analysis\2025_Fouquerel\analysis\250320_nuclei_masks'

os.makedirs(masks_dir, exist_ok=True)

# %%
# get all the nd2 files from the selected directory
file_list = [x for x in os.listdir(data_dir) if x.endswith('.nd2')]
file_list.sort()
file_list
# Out:
# ['Batch Deconvolution_000_clone14_siPRKDC_20minDL_0h_002.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_20minDL_0h_003.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_20minDL_0h_004.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_20minDL_0h_005.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_20minDL_0h_006.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_20minDL_0h_007.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_20minDL_0h_008.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_20minDL_0h_009.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_20minDL_0h_010.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_20minDL_0h_011.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_20minDL_0h_012.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_20minDL_0h_013.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_20minDL_24h_001.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_20minDL_24h_002.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_20minDL_24h_003.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_20minDL_24h_004.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_20minDL_24h_005.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_20minDL_24h_006.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_20minDL_24h_007.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_20minDL_24h_008.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_20minDL_24h_009.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_20minDL_24h_010.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_unt_001.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_unt_002.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_unt_003.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_unt_004.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_unt_005.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_unt_006.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_unt_007.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_unt_008.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_unt_009.nd2',
#  'Batch Deconvolution_000_clone14_siPRKDC_unt_010.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_20minDL_0h_002.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_20minDL_0h_003.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_20minDL_0h_004.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_20minDL_0h_005.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_20minDL_0h_006.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_20minDL_0h_007.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_20minDL_0h_008.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_20minDL_0h_009.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_20minDL_0h_010.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_20minDL_0h_011.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_20minDL_0h_012.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_20minDL_24h_001.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_20minDL_24h_002.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_20minDL_24h_003.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_20minDL_24h_004.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_20minDL_24h_005.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_20minDL_24h_006.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_20minDL_24h_007.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_20minDL_24h_008.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_20minDL_24h_009.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_20minDL_24h_010.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_20minDL_24h_011.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_unt_001.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_unt_002.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_unt_003.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_unt_004.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_unt_005.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_unt_006.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_unt_007.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_unt_008.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_unt_009.nd2',
#  'Batch Deconvolution_000_clone14_untransfected_unt_010.nd2']

# %%
# use to run the analysis only on a selected file(s)
file_list = ['Batch Deconvolution_000_clone14_siPRKDC_20minDL_0h_002.nd2']

# %%
for file_name in file_list:

    im_path = os.path.join(data_dir, file_name)
    t = ND2Reader(im_path)

    # find the sharpest frame in the stack
    foci1_stack = np.array([t.get_frame_2D(c=1, z=z) for z in range(t.sizes['z'])])
    sharpest_index = sharpest_frame_laplacian(foci1_stack)

    # get images from the sharpest frame
    dapi_im = t.get_frame_2D(c=0, z=sharpest_index)
    foci1_im = t.get_frame_2D(c=1, z=sharpest_index)
    foci2_im = t.get_frame_2D(c=2, z=sharpest_index)

    # segment the image
    mask,_,_,_ = model.eval(dapi_im, diameter=cell_diameter, flow_threshold=None)

    # clear the border
    mask_border_clear = clear_border(mask)

    # save the mask
    mask_path = os.path.join(masks_dir, file_name[:-4] + '_mask.png')
    imsave(mask_path, mask_border_clear.astype(np.uint16))

    # detect foci
    foci1 = blob_log(foci1_im, min_sigma = 2, max_sigma=30, num_sigma = 10, threshold=foci1_threshold)
    foci2 = blob_log(foci2_im, min_sigma = 2, max_sigma=30, num_sigma = 10, threshold=foci2_threshold)

    # quantify cells
    df_cell = pd.DataFrame(regionprops_table(mask_border_clear, properties=('label', 'area', 'centroid','bbox','image')))
    df_cell['image'] = file_name
    df_cell['condition'] = '_'.join(file_name.split('_')[3:-1])
    df_cell['frame'] = sharpest_index

    # select cells within the size range
    df_cell = df_cell[(df_cell['area'] > min_area) & (df_cell['area'] < max_area)]
    df_cell = df_cell.reset_index(drop=True)

    # recreate nuclei mask
    mask_border_clear = mask_from_df(df_cell, shape = mask_border_clear.shape)
    # drop the image column
    df_cell = df_cell.drop(columns=['image'])
    df_cell.columns = ['cell', 'area', 'centroid-0', 'centroid-1', 'bbox-0', 'bbox-1', 'bbox-2', 'bbox-3']

    # quantify foci
    df_foci1 = pd.DataFrame(foci1, columns=['y', 'x', 'r'])
    df_foci1['cell'] = mask_border_clear[foci1[:,0].astype(int), foci1[:,1].astype(int)]

    df_foci2 = pd.DataFrame(foci2, columns=['y', 'x', 'r'])
    df_foci2['cell'] = mask_border_clear[foci2[:,0].astype(int), foci2[:,1].astype(int)]

    # count foci per cell
    df_foci1_count = df_foci1.groupby('cell').size().reset_index(name='foci1_count')
    df_foci2_count = df_foci2.groupby('cell').size().reset_index(name='foci2_count')
    df_cell = df_cell.merge(df_foci1_count, on='cell', how='left').merge(df_foci2_count, on='cell', how='left')

    # quantify foci pairs
    for cell in df_cell['cell']:
        
        # Select points for this cell
        foci1_cell = df_foci1.loc[df_foci1['cell'] == cell,['y', 'x']].values
        foci2_cell = df_foci2.loc[df_foci2['cell'] == cell,['y', 'x']].values
        
        if len(foci1_cell) == 0 or len(foci2_cell) == 0:
            continue

        # Compute pairwise distances
        distances = cdist(foci1_cell, foci2_cell, metric='euclidean')
        
        for d in dist_list:
            count = np.sum(distances < d)
            df_cell.loc[df_cell['cell'] == cell, f'foci1_foci2_{d}'] = count

    # save the data
    df_cell.to_csv(os.path.join(masks_dir, file_name[:-4] + '_cell_data.csv'), index=False)
    df_foci1.to_csv(os.path.join(masks_dir, file_name[:-4] + '_foci1_data.csv'), index=False)
    df_foci2.to_csv(os.path.join(masks_dir, file_name[:-4] + '_foci2_data.csv'), index=False)
# Out:
# c:\Users\KMK280\AppData\Local\miniconda3\envs\cellpose-env\Lib\site-packages\skimage\_shared\utils.py:328: UserWarning: I:\CBI\Kasia\data_analysis\2025_Fouquerel\analysis\250320_nuclei_masks\Batch Deconvolution_000_clone14_siPRKDC_20minDL_0h_002_mask.png is a low contrast image
#   return func(*args, **kwargs)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\KMK280\AppData\Local\miniconda3\envs\cellpose-env\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 41
#      38 df_cell = df_cell.reset_index(drop=True)
#      40 # recreate nuclei mask
# ---> 41 mask_border_clear = mask_from_df(df_cell, shape = mask_border_clear.shape)
#      42 # drop the image column
#      43 df_cell = df_cell.drop(columns=['image'])
#
# File i:\CBI\Kasia\data_analysis\2025_Fouquerel\foci_analysis\utils.py:50, in mask_from_df(df, shape, prefix)
#      48     col_stop = int(row[f'{prefix}bbox-3'])
#      49     patch = mask[row_start:row_stop, col_start:col_stop]
# ---> 50     mask[row_start:row_stop, col_start:col_stop] = patch + row[f'{prefix}image']*row[f'{prefix}label']
#      51 return mask
#
# File c:\Users\KMK280\AppData\Local\miniconda3\envs\cellpose-env\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File c:\Users\KMK280\AppData\Local\miniconda3\envs\cellpose-env\Lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File c:\Users\KMK280\AppData\Local\miniconda3\envs\cellpose-env\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'label'
